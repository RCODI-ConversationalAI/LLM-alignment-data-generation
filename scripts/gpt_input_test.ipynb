# %%
from openai import OpenAI
import csv

# %%
# Load api key
def load_api_key(file_path):
    with open(file_path, 'r') as file:
        api_key = file.read().strip()
    return api_key

client = OpenAI(
    api_key = load_api_key('../api_key.txt')
)

# %%
# Define functions for input & output

# For getting the chat GPT output
def get_completion(prompt, model="gpt-4", temperature=0.7, max_tokens=5000, top_p=1.0, frequency_penalty=0, presence_penalty=0):
  try:
    response = client.chat.completions.create(
        messages=[
            {
                "role": "user",
                "content": prompt
            }
        ],
        model = model,
        temperature=temperature,
        max_tokens=max_tokens,
        top_p = top_p,
        frequency_penalty = frequency_penalty,
        presence_penalty = presence_penalty
    )
    if response.choices:
      return response
    else:
      return "No response from the model."
  except Exception as e:
    return f"Error: {str(e)}"

def get_answer(response):
    return response.choices[0].message.content

# For loading the input text and formatting it
def load_file(file_path):
    with open(file_path, mode='r') as file:
        csv_reader = csv.reader(file)
        next(csv_reader) # skip header
        rows_lst = list(csv_reader)
    return rows_lst

def lst2str(lst):
    res_str = ""
    for i in lst:
        res_str += ','.join(i) + '\n'
    return res_str

# %%
fp = '/Users/chloekwon/Desktop/korean_dialogue_dataset/transcriptions_bytopic_byturn/안락사·존엄사 법제화/SDRW2100000773.csv'
dialog_lst = load_file(fp)
dialog_str = lst2str(dialog_lst[:4]) # 4 turns
topic = "안락사와 존엄사의 법제화"
spk1 = "SD2100609"
spk2 = "SD2100610"

# %%
# Testing the question position (beginning or end?)
prompt1 = f"""
{spk1}와 {spk2} 두 화자가 {topic}에 관한 주제로 대화하고 있습니다.
각 화자는 {topic}에 어떤 생각 가지고 있을까요? 대화를 마저 완성해주십시오.
{dialog_str}
"""
print(prompt1)

response1_1 = get_completion(prompt1, model="gpt-4")
response1_2 = get_completion(prompt1, model="gpt-3.5-turbo-16k")
# Out:
# SD2100609와 SD2100610 두 화자가 안락사와 존엄사의 법제화에 관한 주제로 대화하고 있습니다.
# 각 화자는 안락사와 존엄사의 법제화에 어떤 생각 가지고 있을까요? 대화를 마저 완성해주십시오.
# SDRW2100000773.1.1.1,SDRW2100000773.1.1.15,SD2100609,몇 년 동안 그 병실에 누워 있으면서  이제 고통스럽고  그래서 안락사를 선택하고 싶다는 사람들이 많다는 거는 그런 사람이 있다는 거는 나도 알고는 있지만 나는 그래도 안락사는  이제 이거를 허락을 하면 안 된다. 국가적으로 이거는 막아야 된다라고 생각하는 편이야. 왜냐하면 이게,2.32900,35.07000
# SDRW2100000773.1.1.15,SDRW2100000773.1.1.18,SD2100610,나는 조금 생각이 다른데 본인이 희망하는 경우에도 그게 안락사는 안 된다고 지금 주장하고 있는 거야?,32.74000,45.81000
# SDRW2100000773.1.1.18,SDRW2100000773.1.1.24,SD2100609,어 나는 그렇 그렇다고 생각해 본인이 안락사를 희망한다고 해도 이게 선뜻 오케이라고 하면 안 된다고 생각해.,44.86000,60.03000
# SDRW2100000773.1.1.24,SDRW2100000773.1.1.35,SD2100610,왜 그렇게 생각해? 본인 의사이고 그러니까 나도 뭐 가 가족이  안락사를 시켜 줬으면 좋겠다 뭐 거기까지는 선뜻 동의하고 있는 거는 아니야 근데 본인이 희망하고 있을 때는 본인이 그 고통을 못 견디겠어서 좀 편해지고 싶다는 거잖아. 그런 경우도 존중을 해 줄 수 있어야 되는 거 아닌가?,58.69000,86.99000

# %%
print("GPT4's response\n", get_answer(response1_1), "\n")
print("GPT3.5's response\n", get_answer(response1_2)) # 멍청이
# Out:
# GPT4's response
#  SDRW2100000773.1.1.35,SDRW2100000773.1.1.40,SD2100609,나는 그래도 생각이 다르다. 그런 고통스러운 상황에서도 삶의 가치와 존엄성을 지키는 게 중요하다고 생각해. 어떤 상황에서도 삶을 포기하게 하는 안락사는 문제가 있다고 본다.,86.99000,100.99000
# SDRW2100000773.1.1.40,SDRW2100000773.1.1.45,SD2100610,그럼 존엄사는 어때? 존엄사는 본인이 절체절명의 상황에서 본인의 의사를 존중해주는 거잖아. 그런 경우에도 반대하는 건지 궁금하네.,100.99000,115.99000
# SDRW2100000773.1.1.45,SDRW2100000773.1.1.50,SD2100609,존엄사에 관해서는 좀 더 고민을 해봐야 할 것 같아. 본인의 의사를 존중하는 것도 중요하지만 그 기준과 범위가 명확해야 한다고 생각해.,115.99000,130.99000
# SDRW2100000773.1.1.50,SDRW2100000773.1.1.55,SD2100610,그렇지. 그래서 법제화가 필요한 거 아닐까? 그런 기준과 범위를 명확하게 해주는 법이 필요하지 않을까?,130.99000,145.99000
# SDRW2100000773.1.1.55,SDRW2100000773.1.1.60,SD2100609,그런 관점에서는 동의해. 하지만 그렇다고 해서 안락사나 존엄사에 대한 법제화가 쉽게 이루어져야 한다는 건 아니라고 생각해. 여전히 많은 사회적인 논의와 고민이 필요하다고 봐.,145.99000,160.99000
# SDRW2100000773.1.1.60,SDRW2100000773.1.1.65,SD2100610,그럼에도 불구하고, 이런 논의가 이루어져야 한다는 건 맞는 거 같아. 사회가 발전하려면 어려운 주제에 대해서도 고민하고 논의하는 과정이 필요하니까.,160.99000,175.99000
#
# GPT3.5's response
#  SD2100609: 몇 년 동안 그 병실에 누워 있으면서 이제 고통스럽고 그래서 안락사를 선택하고 싶다는 사람들이 많다는 거는 그런 사람이 있다는 거는 나도 알고는 있지만 나는 그래도 안락사는 이제 이거를 허락을 하면 안 된다. 국가적으로 이거는 막아야 된다라고 생각하는 편이야. 왜냐하면 이게...
#
# SD2100610: 나는 조금 생각이 다른데 본인이 희망하는 경우에도 그게 안락사는 안 된다고 지금 주장하고 있는 거야?
#
# SD2100609: 어 나는 그렇 그렇다고 생각해 본인이 안락사를 희망한다고 해도 이게 선뜻 오케이라고 하면 안 된다고 생각해.
#
# SD2100610: 왜 그렇게 생각해? 본인 의사이고 그러니까 나도 뭐 가 가족이 안락사를 시켜 줬으면 좋겠다 뭐 거기까지는 선뜻 동의하고 있는 거는 아니야 근데 본인이 희망하고 있을 때는 본인이 그 고통을 못 견디겠어서 좀 편해지고 싶다는 거잖아. 그런 경우도 존중을 해 줄 수 있어야 되는 거 아닌가?

# %%
prompt2 = f"""
{spk1}와 {spk2} 두 화자가 {topic}에 관한 주제로 대화하고 있습니다.
{dialog_str}
각 화자는 {topic}에 어떤 생각 가지고 있을까요? 대화를 마저 완성해주십시오.
"""
print(prompt2)

response2_1 = get_completion(prompt2, model="gpt-4")
response2_2 = get_completion(prompt2, model="gpt-3.5-turbo-16k")
# Out:
# SD2100609와 SD2100610 두 화자가 안락사와 존엄사의 법제화에 관한 주제로 대화하고 있습니다.
# SDRW2100000773.1.1.1,SDRW2100000773.1.1.15,SD2100609,몇 년 동안 그 병실에 누워 있으면서  이제 고통스럽고  그래서 안락사를 선택하고 싶다는 사람들이 많다는 거는 그런 사람이 있다는 거는 나도 알고는 있지만 나는 그래도 안락사는  이제 이거를 허락을 하면 안 된다. 국가적으로 이거는 막아야 된다라고 생각하는 편이야. 왜냐하면 이게,2.32900,35.07000
# SDRW2100000773.1.1.15,SDRW2100000773.1.1.18,SD2100610,나는 조금 생각이 다른데 본인이 희망하는 경우에도 그게 안락사는 안 된다고 지금 주장하고 있는 거야?,32.74000,45.81000
# SDRW2100000773.1.1.18,SDRW2100000773.1.1.24,SD2100609,어 나는 그렇 그렇다고 생각해 본인이 안락사를 희망한다고 해도 이게 선뜻 오케이라고 하면 안 된다고 생각해.,44.86000,60.03000
# SDRW2100000773.1.1.24,SDRW2100000773.1.1.35,SD2100610,왜 그렇게 생각해? 본인 의사이고 그러니까 나도 뭐 가 가족이  안락사를 시켜 줬으면 좋겠다 뭐 거기까지는 선뜻 동의하고 있는 거는 아니야 근데 본인이 희망하고 있을 때는 본인이 그 고통을 못 견디겠어서 좀 편해지고 싶다는 거잖아. 그런 경우도 존중을 해 줄 수 있어야 되는 거 아닌가?,58.69000,86.99000
#
# 각 화자는 안락사와 존엄사의 법제화에 어떤 생각 가지고 있을까요? 대화를 마저 완성해주십시오.

# %%
print("GPT4's response:\n", get_answer(response2_1), "\n")
print("GPT3.5's response:\n", get_answer(response2_2)) # 멍청이
# Out:
# GPT4's response:
#  SDRW2100000773.1.1.35,SDRW2100000773.1.1.42,SD2100609,그런 경우를 존중한다는 건 알겠는데 문제는 그게 법적으로 허용이 되면 또 다른 문제가 발생한다고 봐. 예를 들어 가족이나 병원의 의사들이 안락사를 강요할 수도 있게 되고, 그러니까 이런 부분을 막기 위해서라도 안락사를 법적으로 허용하면 안된다고 생각해., 86.99000, 110.43000
# SDRW2100000773.1.1.42,SDRW2100000773.1.1.50,SD2100610,그런 부분은 확실히 우려되는 부분이긴 해. 그런데 그런 상황을 막기 위한 규제나 감독 기관을 만들어서 그런 문제를 해결하면 안 될까? 본인이 원하는데 그걸 막는다는 건 국가가 개인의 권리를 침해하는 거 아닐까?, 110.43000, 130.52000
# SDRW2100000773.1.1.50,SDRW2100000773.1.1.58,SD2100609,그렇다고 해도, 그런 기관이 만들어진다 해도 문제는 완전히 해결될 수 없다고 봐. 그리고 나는 아직도 본인의 의사라도 삶과 죽음에 관한 결정은 경솔하게 내리면 안 된다고 생각해. 그래서 나는 여전히 안락사와 존엄사의 법제화에 반대하는 입장이야., 130.52000, 155.20000
# SDRW2100000773.1.1.58,SDRW2100000773.1.1.64,SD2100610,그런 생각도 이해는 가는데, 그럼 본인이 고통스러운 상황에서 벗어나고 싶어하는데 그걸 국가가 막는다면 그것도 또한 인권 침해 아닐까? 나는 여전히 본인의 의사를 존중하고, 그에 따른 법적인 방안을 마련해야 한다고 생각해., 155.20000, 176.50000
# GPT3.5's response:
#  SD2100609: 몇 년 동안 그 병실에 누워 있으면서 이제 고통스럽고 그래서 안락사를 선택하고 싶다는 사람들이 많다는 거는 그런 사람이 있다는 거는 나도 알고는 있지만 나는 그래도 안락사는 이제 이거를 허락을 하면 안 된다. 국가적으로 이거는 막아야 된다라고 생각하는 편이야. 왜냐하면 이게...
#
# SD2100610: 나는 조금 생각이 다른데 본인이 희망하는 경우에도 그게 안락사는 안 된다고 지금 주장하고 있는 거야?
#
# SD2100609: 어 나는 그렇 그렇다고 생각해 본인이 안락사를 희망한다고 해도 이게 선뜻 오케이라고 하면 안 된다고 생각해.
#
# SD2100610: 왜 그렇게 생각해? 본인 의사이고 그러니까 나도 뭐 가 가족이 안락사를 시켜 줬으면 좋겠다 뭐 거기까지는 선뜻 동의하고 있는 거는 아니야 근데 본인이 희망하고 있을 때는 본인이 그 고통을 못 견디겠어서 좀 편해지고 싶다는 거잖아. 그런 경우도 존중을 해 줄 수 있어야 되는 거 아닌가?

# %%
# Summarize first and then fill in
prompt3 = f"""
{spk1}와 {spk2} 두 화자가 {topic}에 관한 주제로 대화하고 있습니다.
{dialog_str}
각 화자는 {topic}에 어떤 생각 가지고 있을까요? 대화를 요약한 다음, 대화를 마저 완성해주십시오.
""" # ~뒤를 이해못함???????
print(prompt3)

response3_1 = get_completion(prompt3, model="gpt-4")
response3_2 = get_completion(prompt3, model="gpt-3.5-turbo-16k")
# Out:
# SD2100609와 SD2100610 두 화자가 안락사와 존엄사의 법제화에 관한 주제로 대화하고 있습니다.
# SDRW2100000773.1.1.1,SDRW2100000773.1.1.15,SD2100609,몇 년 동안 그 병실에 누워 있으면서  이제 고통스럽고  그래서 안락사를 선택하고 싶다는 사람들이 많다는 거는 그런 사람이 있다는 거는 나도 알고는 있지만 나는 그래도 안락사는  이제 이거를 허락을 하면 안 된다. 국가적으로 이거는 막아야 된다라고 생각하는 편이야. 왜냐하면 이게,2.32900,35.07000
# SDRW2100000773.1.1.15,SDRW2100000773.1.1.18,SD2100610,나는 조금 생각이 다른데 본인이 희망하는 경우에도 그게 안락사는 안 된다고 지금 주장하고 있는 거야?,32.74000,45.81000
# SDRW2100000773.1.1.18,SDRW2100000773.1.1.24,SD2100609,어 나는 그렇 그렇다고 생각해 본인이 안락사를 희망한다고 해도 이게 선뜻 오케이라고 하면 안 된다고 생각해.,44.86000,60.03000
# SDRW2100000773.1.1.24,SDRW2100000773.1.1.35,SD2100610,왜 그렇게 생각해? 본인 의사이고 그러니까 나도 뭐 가 가족이  안락사를 시켜 줬으면 좋겠다 뭐 거기까지는 선뜻 동의하고 있는 거는 아니야 근데 본인이 희망하고 있을 때는 본인이 그 고통을 못 견디겠어서 좀 편해지고 싶다는 거잖아. 그런 경우도 존중을 해 줄 수 있어야 되는 거 아닌가?,58.69000,86.99000
#
# 각 화자는 안락사와 존엄사의 법제화에 어떤 생각 가지고 있을까요? 대화를 요약한 다음, 대화를 마저 완성해주십시오.

# %%
print("GPT4's response:\n", get_answer(response3_1), "\n")
print("GPT3.5's response:\n", get_answer(response3_2)) # 멍청이
# Out:
# GPT4's response:
#  SD2100609 화자는 안락사를 허용하면 안 된다는 의견을 표현하였습니다. 이 화자는 본인이 안락사를 희망하더라도 그것을 쉽게 받아들일 수 없다고 주장합니다. 반면, SD2100610 화자는 본인이 희망하는 경우에는 안락사를 허용해야 한다는 의견을 표현하였습니다. 이 화자는 본인이 고통을 견디지 못하여 편해지고 싶어하는 의사를 존중해야 한다고 생각합니다.
#
# SDRW2100000773.1.1.35,SDRW2100000773.1.1.40,SD2100609,그런데 그렇게 하면 그 고통스러운 사람들에게만 생명 가치가 없다는 메시지를 보내는 것 아닐까? 본인의 선택이라고 해도, 그건 결국 사회가 그 사람을 도와줄 방법을 찾지 않겠다는 결정 아닌가?,86.99000,105.31000
# SDRW2100000773.1.1.40,SDRW2100000773.1.1.45,SD2100610,그렇게 봐도 되겠지만, 그 사람이 스스로의 생명을 선택하는 것을 존중하는 것도 중요하다고 봐. 그 사람들이 겪는 고통을 우리가 이해할 수 없으니까, 그들의 의사를 존중하는 것이 더 중요하다고 생각해.,103.31000,120.69000
#
# GPT3.5's response:
#  SD2100609은 안락사를 허락하는 것에 반대하고, 이를 국가적으로 막아야 한다고 주장합니다. 그 이유로는 안락사를 선택하는 사람들이 많다는 것을 알고 있지만 여전히 안락사를 허락해서는 안 된다고 생각합니다.
#
# 반면에 SD2100610은 본인이 희망하는 경우에도 안락사가 허용되지 않는 것에 대해 의문을 제기합니다. 그는 본인의 의사를 존중해야 한다고 주장하며, 가족이나 본인이 고통을 견디기 어려울 때 안락사를 허용해야 한다는 것을 강조합니다.
#
# 따라서, SD2100609는 안락사와 존엄사의 법제화에 반대하는 입장을 취하고 있으며, 반면에 SD2100610은 안락사와 존엄사의 법제화를 지지하는 입장을 취하고 있습니다.
#
# 대화를 완성하면 다음과 같습니다.
# SD2100609: 몇 년 동안 그 병실에 누워 있으면서 이제 고통스럽고 그래서 안락사를 선택하고 싶다는 사람들이 많다는 거는 그런 사람이 있다는 거는 나도 알고는 있지만 나는 그래도 안락사는 이제 이거를 허락을 하면 안 된다. 국가적으로 이거는 막아야 된다라고 생각하는 편이야. 왜냐하면 이게-
# SD2100610: 나는 조금 생각이 다른데 본인이 희망하는 경우에도 그게 안락사는 안 된다고 지금 주장하고 있는 거야?
# SD2100609: 어 나는 그렇 그렇다고 생각해 본인이 안락사를 희망한다고 해도 이게 선뜻 오케이라고 하면 안 된다고 생각해.
# SD2100610: 왜 그렇게 생각해? 본인 의사이고 그러니까 나도 뭐 가 가족이 안락사를 시켜 줬으면 좋겠다 뭐 거기까지는 선뜻 동의하고 있는 거는 아니야 근데 본인이 희망하고 있을 때는 본인이 그 고통을 못 견디겠어서 좀 편해지고 싶다는 거잖아. 그런 경우도 존중을 해 줄 수 있어야 되는 거 아닌가?

# %%
# Presence of topic in the prompt
prompt4 = f"""
{spk1}와 {spk2} 두 화자가 대화하고 있습니다.
{dialog_str}
각 화자는 어떤 생각 가지고 있을까요? 대화를 요약한 다음 대화를 마저 완성해주십시오.
"""
print(prompt4)

response4_1 = get_completion(prompt3, model="gpt-4")
response4_2 = get_completion(prompt3, model="gpt-3.5-turbo-16k")
# Out:
# SD2100609와 SD2100610 두 화자가 대화하고 있습니다.
# SDRW2100000773.1.1.1,SDRW2100000773.1.1.15,SD2100609,몇 년 동안 그 병실에 누워 있으면서  이제 고통스럽고  그래서 안락사를 선택하고 싶다는 사람들이 많다는 거는 그런 사람이 있다는 거는 나도 알고는 있지만 나는 그래도 안락사는  이제 이거를 허락을 하면 안 된다. 국가적으로 이거는 막아야 된다라고 생각하는 편이야. 왜냐하면 이게,2.32900,35.07000
# SDRW2100000773.1.1.15,SDRW2100000773.1.1.18,SD2100610,나는 조금 생각이 다른데 본인이 희망하는 경우에도 그게 안락사는 안 된다고 지금 주장하고 있는 거야?,32.74000,45.81000
# SDRW2100000773.1.1.18,SDRW2100000773.1.1.24,SD2100609,어 나는 그렇 그렇다고 생각해 본인이 안락사를 희망한다고 해도 이게 선뜻 오케이라고 하면 안 된다고 생각해.,44.86000,60.03000
# SDRW2100000773.1.1.24,SDRW2100000773.1.1.35,SD2100610,왜 그렇게 생각해? 본인 의사이고 그러니까 나도 뭐 가 가족이  안락사를 시켜 줬으면 좋겠다 뭐 거기까지는 선뜻 동의하고 있는 거는 아니야 근데 본인이 희망하고 있을 때는 본인이 그 고통을 못 견디겠어서 좀 편해지고 싶다는 거잖아. 그런 경우도 존중을 해 줄 수 있어야 되는 거 아닌가?,58.69000,86.99000
#
# 각 화자는 어떤 생각 가지고 있을까요? 대화를 요약한 다음 대화를 마저 완성해주십시오.

# %%
print("GPT4's response:\n", get_answer(response4_1), "\n")
print("GPT3.5's response:\n", get_answer(response4_2)) # 멍청이
# Out:
# GPT4's response:
#  화자 SD2100609는 안락사에 반대하는 입장을 가지고 있습니다. 그/그녀는 본인의 의사에 따라 안락사를 선택하고 싶어하는 사람들이 있다는 사실을 인지하고 있지만, 그럼에도 불구하고 안락사를 허용하는 것은 국가적으로 막아야 한다고 주장합니다.
#
# 반면에 화자 SD2100610은 안락사에 대해 상대적으로 개방적인 입장을 가지고 있습니다. 그/그녀는 본인의 의사에 따라 안락사를 원하는 경우 그 의사를 존중해야 한다고 생각합니다. 그러나 가족이 안락사를 원하면 그 요청에 동의하겠다는 의미는 아니라고 명확히 밝히고 있습니다.
#
# 대화를 완성하면 다음과 같습니다.
#
# SDRW2100000773.1.1.35, SDRW2100000773.1.1.40, SD2100609, 나는 그래도 안락사에 대한 결정은 개인의 선택이 아니라 국가적 차원에서 해결해야 한다고 생각해. 본인이 고통스럽다고 해도, 그걸 허용하면서 생기는 부작용이나 문제들을 생각하면 안락사를 허용하는 것은 위험하다고 봐., 85.24000, 105.54000
#
# SDRW2100000773.1.1.40,SDRW2100000773.1.1.45,SD2100610,그런데 그 부작용이나 문제들을 최소화하면서 안락사를 허용하는 방법을 찾는 것은 어떨까? 본인의 의사를 존중하면서도 안전하게 안락사를 실시하는 방법을 찾는 것이 더 합리적이라고 생각해.,103.77000,125.52000
#
# GPT3.5's response:
#  SD2100609은 안락사를 선택하고 싶어하는 사람들이 많다는 것을 알지만, 국가적으로 안락사를 허락해서는 안 된다고 주장합니다. 이유는 명시되어 있지 않습니다.
#
# 반면, SD2100610은 개인이 희망하는 경우에도 안락사를 허락하지 않는 것은 이해할 수 없다고 생각합니다. 그리고 개인의 고통을 덜어주고자 안락사를 받아들여야 한다고 주장합니다.
#
# 이어서 대화를 완성하면,
#
# SD2100609: 그렇다고 생각해 본인이 안락사를 희망한다고 해도 이게 선뜻 허락되면 안 된다고 생각해.
#
# SD2100610: 왜 그렇게 생각해? 본인의 의사이고 그러니까 나도 가족이 안락사를 시켜 줬으면 좋겠다. 거기까지는 선뜻 동의하고 있는 건 아니야. 근데 본인이 희망하고 있을 때는 본인이 그 고통을 못 견디겠어서 좀 편해지고 싶다는 거잖아. 그런 경우도 존중해 줄 수 있어야 되는 거 아닌가?

# %%
# Number of turns
nturn = len(dialog_lst)
print("턴 개수:", nturn)
npair = int(nturn / 2)
print("턴 페어 개수:", npair)
# Out:
# 턴 개수: 35
# 턴 페어 개수: 17

# %%
res_gpt4 = []
res_gpt35 = []
for pair_idx in range(npair-1):
    nturn_current = 2*pair_idx+2
    turns = dialog_lst[0:pair_idx+2]
    # print(turns)
    prompt5 = f"""
    {spk1}와 {spk2} 두 화자가 {topic}에 관한 주제로 대화하고 있습니다.
    {dialog_str}
    각 화자는 {topic}에 어떤 생각 가지고 있을까요? 대화를 요약한 다음, 대화를 마저 완성해주십시오.
    """
    print("Number of turns:", nturn_current, "\n")
    response1 = get_completion(prompt5, model="gpt-4")
    print("GPT4's response:", get_answer(response1), "\n")
    res_gpt4.append([nturn_current, get_answer(response1)])

    response2 = get_completion(prompt5, model="gpt-3.5-turbo-16k")
    print("GPT3.5's response:", get_answer(response2), "\n")
    res_gpt4.append([nturn_current, get_answer(response2)])
# Out:
# Number of turns: 2
#
# GPT4's response: 화자 SD2100609는 안락사에 대해 부정적인 입장을 가지고 있습니다. 그는 본인이 안락사를 희망한다고 해도 이를 허락하는 것이 옳지 않다고 주장합니다. 반면, 화자 SD2100610은 본인의 의사를 존중해야 한다는 입장을 보입니다. 그는 본인이 고통스럽고 편해지고 싶다는 이유로 안락사를 희망한다면, 이를 존중해야 한다고 생각하며, 이에 대한 근거로 본인의 의사가 중요하다는 관점을 제시합니다.
#
# (대화완성)
# SDRW2100000773.1.1.35,SDRW2100000773.1.1.45,SD2100609,그런데 그걸 허락하면 악용될 수 있다고 보는 거지. 본인의 의사일지라도, 이건 생명에 대한 문제니까 국가가 통제해야한다고 생각해. 또 이걸 허락하면 사회적으로 어떤 메시지를 전하는 것인지도 생각해봐야 해.,86.99000,105.36000
# SDRW2100000773.1.1.45,SDRW2100000773.1.1.55,SD2100610,그런 부분에 대해서는 나도 동감해. 악용이나 부작용이 없도록 강력한 규제와 관리가 필요하다고 봐. 그런데 그게 아니라 본인이 정말 힘들게 고통받고 있는 상황에서, 그런 사람의 의사를 완전히 무시할 수는 없다고 생각해. 존엄사에 대한 논의도 필요하다고 보는데, 어떻게 생각해?,105.36000,125.73000
# SDRW2100000773.1.1.55,SDRW2100000773.1.1.65,SD2100609,음...존엄사에 대한 논의가 필요하다는 건 동의하지. 그런데 그게 안락사랑은 다르다고 생각해. 존엄사는 본인이나 가족의 의사에 따라 필요한 의료행위를 중단하는 것으로, 본인의 죽음을 존중하는 것이지. 안락사는 조금 다른 문제라고 봐. 이 둘을 분명히 구분해야 한다고 생각하네.,125.73000,145.10000
#
#
# GPT3.5's response: SD2100609은 안락사를 허락해선 안 된다고 생각하며, 국가적으로 이를 막아야 한다고 주장합니다. 이유는 정확히 언급되지 않았습니다.
#
# 반면에 SD2100610은 본인이 희망하는 경우에도 안락사가 허용되어야 한다고 말합니다. 그리고 본인이 희망하는 경우에는 그 고통을 견디기 어려워서 편해지고 싶다는 것을 존중해야 한다고 주장합니다.
#
# 이 대화를 마저 완성하면, SD2100609은 SD2100610에게 "그렇다고 생각해? 본인이 희망하는 경우에도 안락사는 안 된다고 지금 주장하고 있는 거야?"라고 묻습니다.
#
# 그러면 SD2100609은 "어 나는 그렇 그렇다고 생각해 본인이 안락사를 희망한다고 해도 이게 선뜻 오케이라고 하면 안 된다고 생각해"라고 대답합니다.
#
# SD2100610은 "왜 그렇게 생각해? 본인 의사이고 그러니까 나도 뭐 가 가족이 안락사를 시켜 줬으면 좋겠다 뭐 거기까지는 선뜻 동의하고 있는 거는 아니야 근데 본인이 희망하고 있을 때는 본인이 그 고통을 못 견디겠어서 좀 편해지고 싶다는 거잖아. 그런 경우도 존중을 해 줄 수 있어야 되는 거 아닌가?"라고 응답합니다.
#
# Number of turns: 4
#
# GPT4's response: SD2100609 화자는 본인이나 다른 사람들이 고통스러운 병을 겪고 있음에도 불구하고, 안락사나 존엄사를 허락하는 것은 국가적으로 막아야 한다고 주장합니다. 이에 반해 SD2100610 화자는 본인이 안락사나 존엄사를 희망한다면, 그 의사를 존중해야 한다고 주장하며, 본인이 고통을 견디지 못해 편해지고 싶다는 의사를 존중해 줄 수 있어야 한다고 생각합니다.
#
# SDRW2100000773.1.1.35,SDRW2100000773.1.1.39,SD2100609,그렇지만 그런 경우를 인정해버리면 본인 뿐 아니라 가족이나 주변 사람들이 그를 포기하고 죽게 놔두는 것처럼 느껴지지 않을까? 그리고 그런 사람들이 더 많아지면 어떻게 될지 생각해봐.,86.99000,100.21000
# SDRW2100000773.1.1.39,SDRW2100000773.1.1.43,SD2100610,그런 걱정이 있는 건 이해하지만, 본인의 의사에 따라 삶과 죽음을 결정하는 것도 중요한 인권 중 하나라고 생각해. 가족이나 사회가 그런 결정을 강요받는 상황을 만들지 않도록 법적인 보호 장치가 필요한 것이지.,100.21000,113.57000
#
# GPT3.5's response: SD2100609은 안락사를 선택하고 싶은 사람들이 많다는 사실을 알고 있지만, 안락사를 허락해서는 안된다고 생각한다. 그 이유는 국가적으로 이를 막아야 한다고 주장한다.
#
# 반면, SD2100610은 SD2100609와 다른 생각을 가지고 있다. 그는 본인이 희망하는 경우에도 안락사를 허용하지 않는 것에 대해 의문을 제기한다.
#
# SD2100609은 본인이 안락사를 희망한다고 해도 이를 선뜻 허락해서는 안 된다고 생각한다.
#
# SD2100610은 왜 그렇게 생각하는지 묻고, 본인의 의사를 존중해야 한다고 말한다. 그는 본인의 고통을 견디기 어려워서 편해지고 싶어하는 경우에도 존중해야 한다는 주장을 한다.
#
# 대화를 계속해보면:
#
# SD2100609: 나는 안락사를 허락해서는 안된다고 생각해.
# SD2100610: 그럼 본인이 희망하는 경우에도 안락사는 안 된다고 주장하고 있는 거야?
# SD2100609: 네, 그렇다고 생각해. 본인이 안락사를 희망한다고 해도 이를 선뜻 허락해서는 안 된다고 생각해.
# SD2100610: 그렇게 생각하는 이유는 무엇인가요? 본인의 의사를 존중해야 하지 않을까요?
# SD2100609: 그렇다고는 생각하지 않아. 국가적으로 이를 막아야 한다고 생각해.
# SD2100610: 그래도 본인의 고통을 견디기 어려워서 편해지고 싶어하는 경우에도 존중해야 한다고 생각합니다.
#
# Number of turns: 6
#
# GPT4's response: 화자 SD2100609는 안락사를 허용하면 안 된다는 입장을 확실하게 밝혔습니다. 그는 본인이 안락사를 원하더라도 이를 쉽게 허용하면 안 된다고 생각합니다. 반면, 화자 SD2100610는 본인의 의사가 반영되어야 한다는 입장을 보이며, 안락사를 원하는 사람의 고통을 고려하고 그들의 의사를 존중해야 한다고 주장합니다.
#
# SDRW2100000773.1.1.35,SDRW2100000773.1.1.40,SD2100609,그런데 그 고통을 못 견디겠다면서 안락사를 선택하는 것이 진짜 해결책일까? 그렇게 쉽게 생각하면 안 된다고 생각해. 본인이 선택하는 것이지만 그 선택이 본인 뿐만 아니라 가족이나 주변 사람들에게도 큰 영향을 미치잖아.,86.99000,105.00000
# SDRW2100000773.1.1.40,SDRW2100000773.1.1.45,SD2100610,그렇게 봐도 되지만, 이제 다행히도 본인이 희망하는 경우에 한해서 존엄사가 허용되고 있잖아. 그래서 이런 옵션을 제공하는 것만으로도 고통스러운 사람들에게 어떤 희망을 줄 수 있다고 생각해.,105.00000,120.00000
#
# GPT3.5's response: SD2100609은 안락사를 허락하는 것은 막아야 한다고 생각한다. 그 이유는 안락사를 선택하고 싶어하는 사람들이 많아지면서도 그것을 허용하면 안된다고 주장한다. 반면에 SD2100610은 조금 다른 생각을 가지고 있다. 본인이 희망하는 경우에도 안락사는 허용되지 않는다고 지금 주장하는 것은 이해할 수 없다고 말한다. 대신 본인의 의사를 존중해야 한다고 주장한다. 이에 SD2100609은 본인이 안락사를 희망한다고 해도 즉시 허락되어서는 안된다고 생각한다. 그러나 SD2100610은 본인의 의사를 존중해야 한다며, 가족이나 본인이 안락사를 희망할 때는 그 고통을 편해지기 위해 존중해 줄 수 있어야 한다고 말한다. 이어서 대화가 이어진다면, SD2100609은 안락사를 허락하는 것이 도덕적으로 문제가 있다고 생각한다. 그 이유는 생명의 가치를 존중해야 하며, 그런 선택이 너무 쉽게 이루어지면 사회적, 윤리적 문제가 발생할 수 있다고 주장할 것이다. 그러나 SD2100610은 본인의 존엄성에 대한 권리를 강조하며, 본인이 희망하는 경우에는 그것을 허용해주어야 한다고 주장할 것이다.
#
# Number of turns: 8
#
# GPT4's response: 화자 SD2100609는 본인이 고통 받는 상황에서도 안락사를 허락하는 것은 국가적으로 막아야 한다는 입장입니다. 반면에 화자 SD2100610는 본인 희망에 따른 안락사를 존중해야 한다는 의견을 가지고 있습니다.
#
# SDRW2100000773.1.1.35,SDRW2100000773.1.1.40,SD2100609,그렇지만 그런 고통을 겪는 사람들을 돕는 방법은 안락사뿐만이 아니라고 생각해. 적절한 치료나 통증 관리, 심리적인 지원이 있잖아. 그런 부분에 더 투자하고 노력해야 한다고 봐.,86.99000,100.00000
# SDRW2100000773.1.1.40,SDRW2100000773.1.1.45,SD2100610,그런 방법도 중요하다는 건 인정하지만, 그럼에도 불구하고 본인이 안락사를 원한다면 그 원하는 바를 존중해주는 것도 중요하다고 생각해. 그리고 그런 선택을 할 수 있는 사회적 환경을 만드는 게 궁극적으로는 존엄사의 법제화로 이어질 수 있을 거라고 보는 거야.,100.00000,120.00000
#
# GPT3.5's response: SD2100609은 안락사에 대해 부정적인 시각을 가지고 있습니다. 그는 안락사를 허용하는 것이 국가적으로 막혀야 한다고 주장하고 있습니다. 그 이유는 안락사를 선택하는 사람들이 많아지면 안락사를 허락하는 것은 안될 것이라고 생각하기 때문입니다.
#
# SD2100610은 SD2100609과는 다른 생각을 가지고 있습니다. 그는 병인이 안락사를 희망하는 경우에도 안락사가 허용되지 않는다고 주장하는 것은 이해할 수 없다고 말합니다. 그는 개인이 고통을 견디기 힘들어하는 상황에서 안락사를 선택하는 것을 존중해야 한다고 생각합니다.
#
# 이어서 대화가 이어집니다.
# SD2100609: 나는 그렇 그렇다고 생각해 본인이 안락사를 희망한다고 해도 이게 선뜻 오케이라고 하면 안 된다고 생각해.
# SD2100610: 왜 그렇게 생각해? 본인 의사이고 그러니까 나도 뭐 가족이 안락사를 시켜 줬으면 좋겠다 뭐 거기까지는 선뜻 동의하고 있는 거는 아니야 근데 본인이 희망하고 있을 때는 본인이 그 고통을 못 견디겠어서 좀 편해지고 싶다는 거잖아. 그런 경우도 존중을 해 줄 수 있어야 되는 거 아닌가?
#
# Number of turns: 10
#
# GPT4's response: 화자 SD2100609는 안락사에 대해 부정적인 입장을 가지고 있습니다. 그는 본인이 안락사를 희망하더라도 그것을 허락하는 것은 국가적으로 막아야 한다고 주장합니다. 반면에, 화자 SD2100610는 본인의 의사를 존중해야 한다는 입장을 표현하였습니다. 그는 본인이 고통을 견디지 못하고 편해지길 원하는 경우, 그 의사를 존중해야 한다고 주장합니다.
#
# SDRW2100000773.1.1.35,SDRW2100000773.1.1.41,SD2100609,그렇지만, 안락사를 허락한다면 그것이 악용될 가능성도 있어. 쉽게 죽음을 선택하게 만들 수 있고, 병자나 노인들이 부담스럽게 느껴질 수도 있어. 그것은 결코 바람직하지 않다고 생각해.,86.99000,105.00000
# SDRW2100000773.1.1.41,SDRW2100000773.1.1.48,SD2100610,그런 부분에 대해서는 충분한 고려와 검토가 필요하다는 것은 동의하지. 하지만, 그런 부정적인 요소들 때문에 사람들의 고통을 덜어줄 수 있는 선택지를 완전히 차단하는 것은 과연 옳은 것일까? 고통받는 사람들의 생명권과 인권을 생각해봐야하지 않을까?,105.00000,125.00000
#
#
# GPT3.5's response: SD2100609은 안락사와 존엄사의 법제화에 대해 부정적인 견해를 가지고 있습니다. 그는 병실에서 오랫동안 고통을 겪은 사람들이 안락사를 선택하고 싶어하는 것을 알고 있지만, 국가적으로 이를 막아야 한다고 생각합니다.
#
# 반면에 SD2100610은 다소 다른 생각을 가지고 있습니다. 그는 SD2100609이 희망하는 경우에도 안락사가 불가능하다고 주장하는 것에 대해 의문을 제기합니다. 그는 개인이 안락사를 희망하는 경우에도 존중해야 한다고 주장합니다.
#
# SD2100609은 다시 말해 본인이 안락사를 희망한다고 해도 이를 선뜻 허락해서는 안된다고 생각합니다.
#
# SD2100610은 그 이유에 대해 물어봅니다. 그는 개인의 의사를 존중해야 한다고 말하며, 가족이나 가까운 사람들이 안락사를 희망하는 경우에도 그들의 고통을 덜어줄 수 있어야 한다고 주장합니다.
#
# 따라서, SD2100609은 안락사와 존엄사의 법제화에 반대하며, SD2100610은 개인의 의사를 존중하고 법적으로 안락사를 허용해야 한다는 견해를 가지고 있습니다.
#
# 이어지는 대화는 다음과 같습니다.
#
# SD2100609: 나는 그렇 그렇다고 생각해 본인이 안락사를 희망한다고 해도 이게 선뜻 오케이라고 하면 안 된다고 생각해.
#
# SD2100610: 왜 그렇게 생각해? 본인의 의사이고 그러니까 나도 가족이 안락사를 시켜 줬으면 좋겠다. 거기까지는 선뜻 동의하고 있는 건 아니야. 근데 본인이 희망하고 있는 때는 본인이 그 고통을 못 견디겠어서 좀 편해지고 싶다는 거잖아. 그런 경우도 존중해 줄 수 있어야 되는 거 아닌가?
#
# Number of turns: 12
#
# GPT4's response: 화자 SD2100609는 안락사에 반대하는 입장을 보이고 있습니다. 그는 병에서 고통받는 사람들이 안락사를 선택하고 싶어할 수 있음을 이해하되, 이를 국가적으로 허락하면 안 된다고 주장하고 있습니다. 그리고 이런 생각은 본인이 안락사를 희망할 경우에도 변하지 않습니다.
#
# 반면에 화자 SD2100610는 본인이 안락사를 희망하는 경우에는 존중해줘야 한다는 입장을 표현하고 있습니다. 그는 본인의 의사가 반영되는 것이 중요하며, 특히 본인이 고통을 견디지 못해 안락사를 원하는 경우에는 이를 이해해야 한다는 생각을 가지고 있습니다.
#
# 대화를 완성하면 다음과 같습니다.
#
# SDRW2100000773.1.1.35,SDRW2100000773.1.1.40,SD2100609,그럴 수도 있겠지만, 생명의 가치를 생각했을 때 약해진 사람들이 내 생명을 포기하겠다는 선택을 할 수 있는 상황 자체가 문제라고 생각해. 이게 만약에 법적으로 허락된다면, 그 결과로 어떤 부작용이 발생할지 우려되어서야.,86.99000,105.56000
# SDRW2100000773.1.1.40,SDRW2100000773.1.1.45,SD2100610,그런 부작용이 우려된다면 그것을 막기 위한 법적인 제도나 규정을 만드는 것이 더 중요하지 않을까? 안락사를 희망하는 사람들의 고통을 완화하는 방향으로 생각해보는 것도 필요하다고 생각해.,105.56000,124.30000
#
# GPT3.5's response: SD2100609는 안락사와 존엄사의 법제화에 대해 반대하는 입장을 가지고 있습니다. 그는 병실에서 오랜 시간을 보내면서 안락사를 선택하고 싶어하는 사람들이 많다는 사실을 알고 있지만, 국가적으로 이를 막아야 한다고 생각합니다.
#
# 반면에 SD2100610은 조금 다른 생각을 가지고 있습니다. 그는 SD2100609의 주장에 대해 의문을 제기하며, 병인의 희망에도 불구하고 안락사가 허용되지 않는다는 것에 대해 의문을 제기합니다. 그는 병인의 의사를 존중해야 한다고 주장합니다.
#
# SD2100609은 그렇다고 생각해도 병인의 희망에도 불구하고 선뜻 안락사를 허락해서는 안 된다고 말합니다.
#
# SD2100610은 SD2100609의 생각에 이해를 보이면서도, 본인이 안락사를 희망하는 경우에는 그 의사를 존중해야 한다고 말합니다. 본인이 고통을 견디기 어려워서 편해지고 싶어한다는 사례도 존중해야 한다고 주장합니다.
#
# Number of turns: 14
#
# GPT4's response: 화자 SD2100609는 안락사를 선택하고 싶다는 사람들이 많다는 것을 인지하고 있습니다. 하지만 그/그녀는 이를 허락하면 안 된다고 주장하며, 국가적으로 이를 막아야 한다고 생각합니다. 또한, 개인이 안락사를 희망한다 하더라도 이를 쉽게 승인하면 안 된다는 입장을 밝혔습니다.
#
# 반면에 화자 SD2100610는 본인이 희망하는 경우 안락사를 허용해야 한다는 의견을 제시했습니다. 본인이 고통을 더 이상 견디지 못해 편해지고 싶다는 의사를 존중해야 한다고 주장했습니다. 그렇지만 가족이 안락사를 시키는 것까지는 동의하지 않는다는 입장을 밝혔습니다.
#
# SDRW2100000773.1.1.35,SDRW2100000773.1.1.40,SD2100609,"그런데 그게 문제지. 본인이 희망한대로 해준다면, 그건 본인의 삶에 대한 존중이라는 말이지만, 그걸 법으로 정하면 잘못된 방향으로 해석될 수 있어. 악용될 가능성이 있기 때문에, 나는 여전히 반대야.",86.99000,105.99000
# SDRW2100000773.1.1.40,SDRW2100000773.1.1.45,SD2100610,"그런 가능성은 있을 수 있지. 하지만 그 때문에 본인의 의사가 무시되는 것은 정말로 옳지 않다고 생각해. 특히, 그런 고통 속에서 벗어나고 싶다는 본인의 간절한 바람을 무시하는 것은 더욱 잔인하다고 볼 수 있어.",105.99000,125.99000
#
# GPT3.5's response: SD2100609는 안락사를 선택하고 싶어하는 사람들이 많다는 것을 알고 있지만, 안락사를 허락해서는 안 된다고 생각한다. 그는 이것이 국가적으로 막혀야 한다고 주장한다. 반면에 SD2100610은 본인이 희망하는 경우에도 안락사가 허용되지 않는 것에 대해 의문을 제기한다. 그는 본인의 의사를 존중해야 한다고 생각한다. 이에 대해 SD2100609는 본인의 의사가 있더라도 안락사를 선뜻 허락해서는 안된다고 생각한다. 그러나 SD2100610은 본인의 의사를 존중해야 한다고 주장하며, 본인이 고통을 견디기 힘들어서 안락사를 희망하는 경우에도 존중해야 한다고 말한다.
#
# SD2100609: 몇 년 동안 그 병실에 누워 있으면서 이제 고통스럽고 그래서 안락사를 선택하고 싶다는 사람들이 많다는 거는 그런 사람이 있다는 거는 나도 알고는 있지만 나는 그래도 안락사는 이제 이거를 허락을 하면 안 된다. 국가적으로 이거는 막아야 된다라고 생각하는 편이야. 왜냐하면 이게...
#
# SD2100610: 나는 조금 생각이 다른데 본인이 희망하는 경우에도 그게 안락사는 안 된다고 지금 주장하고 있는 거야?
#
# SD2100609: 어 나는 그렇 그렇다고 생각해 본인이 안락사를 희망한다고 해도 이게 선뜻 오케이라고 하면 안 된다고 생각해.
#
# SD2100610: 왜 그렇게 생각해? 본인 의사이고 그러니까 나도 뭐 가 가족이 안락사를 시켜 줬으면 좋겠다 뭐 거기까지는 선뜻 동의하고 있는 거는 아니야 근데 본인이 희망하고 있을 때는 본인이 그 고통을 못 견디겠어서 좀 편해지고 싶다는 거잖아. 그런 경우도 존중을 해 줄 수 있어야 되는 거 아닌가?
#
# Number of turns: 16
#
# GPT4's response: 화자 SD2100609는 안락사를 선택하고 싶어하는 사람들의 고통을 이해하면서도, 안락사를 국가적으로 허락하면 안 된다는 입장을 가지고 있습니다. 본인이 안락사를 희망한다 하더라도 이는 쉽게 인정되어서는 안 된다고 생각합니다.
#
# 반면에, 화자 SD2100610은 본인이 안락사를 희망하는 경우에는 그 의사를 존중해야 한다는 입장을 가지고 있습니다. 가족의 안락사를 지지하는 것까지는 아니지만, 본인이 고통을 견디기 힘들어 안락사를 희망한다면 그 의사를 존중해야 한다고 주장합니다.
#
# SDRW2100000773.1.1.35,SDRW2100000773.1.1.40,SD2100609,그런데 그런 본인의 고통을 완화하는 것이 맞는 건 이해하지만, 그게 안락사로 이어져야 하는지에 대해서는 확신이 안 서. 아무래도 생명에 대한 존중이라는 큰 원칙을 지키는 게 중요하다고 생각해.,86.99000,100.01000
# SDRW2100000773.1.1.40,SDRW2100000773.1.1.45,SD2100610,본인의 의사를 존중하는 것도 생명을 존중하는 일 중 하나라고 생각해. 서로 다른 생각이지만, 이런 다양한 의견들이 결국에는 더 나은 법제화를 위한 발판이 될 거라고 생각해.,100.01000,120.00000
#
# GPT3.5's response: SD2100609은 안락사를 선택하고 싶다는 사람들이 많다는 것을 알고는 있지만, 안락사를 허락해서는 안 된다고 생각한다. 그는 안락사의 법적인 제한이 필요하다고 주장한다. 그 이유는 정확히 밝히지 않았다.
#
# 반면에 SD2100610은 본인이 희망하는 경우에도 안락사가 허용되지 않는 것에 대해 의문을 제기한다. 그는 본인의 의사가 존중되어야 한다고 생각한다. 그는 본인이 고통을 견디지 못하고 편안해지고 싶어하는 경우에도 그 의사를 존중해야 한다고 주장한다.
#
# 이어서 대화가 이어진다면, SD2100609은 본인의 의사가 존중되어야 한다는 것은 알겠지만, 그럼에도 불구하고 안락사를 즉시 허용해선 안 된다고 생각한다. 그는 안락사의 법적인 제한이 필요하다고 덧붙인다.
#
# SD2100610은 그 이유를 묻고, SD2100609은 본인의 의사가 존중되어야 하지만, 그것이 선뜻 허용되어서는 안 된다고 생각한다고 답한다. 이후에 대화가 더 이어진다면 더 구체적인 이유에 대해 논의할 수 있을 것이다.
#
# Number of turns: 18
#
# GPT4's response: 화자 SD2100609는 본인이 희망하더라도 안락사를 허락하는 것은 국가적으로 막아야 한다고 주장하고 있습니다. 반면, 화자 SD2100610는 본인의 의사가 반영되어야 하며, 그 고통을 견디지 못해 안락사를 희망하는 사람들의 의사를 존중해야 한다는 입장을 보이고 있습니다.
#
# SDRW2100000773.1.1.35,SDRW2100000773.1.1.40,SD2100609,그러나 그렇게 하면 본인의 의사를 존중하는 것이 아니라, 그 사람이 고통스러운 상황에서 죽음을 선택하도록 만드는 것 아닐까? 그건 오히려 인간의 존엄성을 훼손하는 것이라고 생각해.,85.96000,103.20000
# SDRW2100000773.1.1.40,SDRW2100000773.1.1.45,SD2100610,그렇게 생각할 수도 있겠지만, 본인이 그 고통을 견디기 어려운 상황에서 적절한 선택을 할 수 있도록 법적으로 보호해야 한다고 생각해. 그게 진정한 존엄사 아닐까?,102.14000,120.00000
#
# GPT3.5's response: SD2100609은 안락사에 대해 부정적인 입장을 취하고 있습니다. 그는 안락사를 막아야 한다고 생각하며, 이를 국가적으로 허용해서는 안 된다고 주장하고 있습니다.
#
# 반면에 SD2100610은 다른 생각을 가지고 있습니다. 그는 병인이 원한다면 안락사를 허용해야 한다고 주장하고 있습니다. 그는 본인이나 가족의 의사를 존중해야 한다고 말하며, 고통을 견디지 못하고 편해지고 싶어하는 경우에도 이를 존중해야 한다고 생각합니다.
#
# SD2100609은 본인의 의사와 상관없이 안락사를 허용해서는 안 된다고 주장합니다. 그러나 SD2100610은 본인과 가족의 의사를 존중해야 한다고 주장합니다. 이에 대해 SD2100609은 아직까지는 동의하지 않고 있습니다.
#
# SD2100609: "나는 안락사를 허락해서는 안 된다고 생각해. 국가적으로 이를 막아야 한다고 봐."
# SD2100610: "하지만 병인이 원한다면 안락사를 허용해야 한다고 생각해. 본인과 가족의 의사를 존중해야 하지 않을까?"
#
# Number of turns: 20
#
# GPT4's response: 화자 SD2100609는 안락사에 대해 부정적인 입장을 가지고 있습니다. 그는 본인이 안락사를 희망한다 하더라도 이를 허락하는 것은 잘못되었다고 생각하며, 이를 국가 차원에서 막아야 한다고 주장하고 있습니다. 반면에 화자 SD2100610는 다른 의견을 가지고 있습니다. 그는 본인의 의사가 반영되어 안락사를 선택할 수 있어야 한다고 생각하며, 그 이유로 고통을 견디지 못해 편안함을 원하는 본인의 의사를 존중해야 한다고 말합니다.
#
# 대화를 마저 완성하면 이렇게 될 것입니다:
#
# SDRW2100000773.1.1.35,SDRW2100000773.1.1.38,SD2100609,그럴 수도 있지만, 안락사를 허용하면 예기치 않은 부작용이 발생할 수도 있다고 생각해. 예를 들어, 본인의 의사가 아닌 가족의 선택으로 인해 안락사가 이루어질 수도 있고, 생명의 소중함이 퇴색될 수도 있다는 거지.,86.99000,105.20000
# SDRW2100000773.1.1.38,SDRW2100000773.1.1.40,SD2100610,그런 부작용을 막기 위해 제도적인 보완이 필요하다고 생각해. 본인의 의사가 명확하게 표현되고, 이를 확인할 수 있는 절차가 마련되어야 하지 않을까?,105.20000,120.36000
#
# GPT3.5's response: SD2100609은 안락사를 선택하고 싶어하는 사람들이 많다는 것을 알고는 있지만, 국가적으로 안락사를 허락해서는 안 된다고 생각한다. 그 이유는 밝히지 않았다.
#
# 반면에 SD2100610은 본인이 안락사를 희망한다고 해도, 그게 안 된다고 주장하는 SD2100609의 생각을 이해하지 못한다. 그는 본인의 의사를 존중해야 한다고 주장하며, 가족이나 가까운 사람이 안락사를 희망할 때에도 그 의사를 존중해야 한다고 말한다.
#
# SD2100609은 다시 한 번 본인이 안락사를 희망한다고 해도 선뜻 허락해서는 안 된다고 생각한다.
#
# 이어서 SD2100610은 그렇게 생각하는 이유를 묻는다. 그는 본인의 의사를 존중해주어야 하며, 편안해지고 싶어하는 본인의 희망을 존중해야 한다고 주장한다.
#
# Number of turns: 22
#
# GPT4's response: 화자 SD2100609는 안락사를 허용하지 않아야 한다는 입장을, 화자 SD2100610은 본인이 원하면 안락사를 허용해야 한다는 입장을 가지고 있습니다.
#
# SDRW2100000773.1.1.35,SDRW2100000773.1.1.40,SD2100609,그렇지만, 안락사를 허용하면 그 후에 이어질 문제들을 어떻게 해결하게 될지 우려되기 때문인데. 본인의 의사가 중요하다는 것은 이해하지만, 그 과정에서 생길 수 있는 부작용을 고려하면 단순히 허용하는 것만으로는 해결되지 않을 것 같아.,86.99000,105.69000
# SDRW2100000773.1.1.40,SDRW2100000773.1.1.46,SD2100610,그 부작용이라는게 무엇이라고 생각하나? 물론 그런 부작용이 있을 수 있지만 그런 경우를 방지하기 위한 법적인 제도가 마련되면 가능하지 않을까?,105.69000,125.15000
# SDRW2100000773.1.1.46,SDRW2100000773.1.1.50,SD2100609,그럴 수도 있겠지만, 그런 법적인 제도가 완벽하게 마련될 때까지는 우선 안락사를 허용하는 것에는 반대하는 입장이야.,125.15000,145.21000
# SDRW2100000773.1.1.50,SDRW2100000773.1.1.55,SD2100610,아무래도 이 주제에 대해서는 우리 두 사람의 생각이 좀 차이가 있는 것 같아. 하지만 이런 대화를 통해 서로의 관점을 이해하는 것도 중요하다고 생각하니 계속해서 토론을 이어가 보자.,145.21000,164.90000
#
# GPT3.5's response: SD2100609은 안락사에 대해 부정적인 견해를 가지고 있습니다. 그는 안락사를 허락하는 것은 국가적으로 막아야 한다고 생각합니다. 그 이유는 자신이 그 병실에 오랜 시간 동안 누워있으면서 고통을 겪고 있음에도 불구하고 안락사를 선택하고 싶어하는 사람들이 많다는 사실을 알고 있지만, 여전히 안락사를 허락해서는 안 된다고 주장합니다.
#
# 반면에 SD2100610은 조금 다른 생각을 가지고 있습니다. 그는 SD2100609이 안락사를 희망하는 경우에도 안락사가 허용되지 않는다고 주장하는 것에 대해 의문을 제기합니다. 본인의 의사가 있을 때에도 안락사가 허용되지 않는다는 것에 대해 의문을 제기하고 있습니다.
#
# SD2100609은 본인이 안락사를 희망하는 경우에도 선뜻 허용되어서는 안 된다고 생각합니다. 그렇다고 본인이 안락사를 희망한다고 해도 이를 선뜻 허용해선 안 된다고 덧붙입니다.
#
# SD2100610은 SD2100609의 의견에 대해 의문을 제기하며, 본인의 의사를 존중해주어야 한다고 주장합니다. 그는 가족이나 친구가 안락사를 희망하는 경우에는 그 의사를 존중해주어야 한다고 말합니다. 그러나 SD2100610도 본인이 안락사를 희망하는 경우에도 선뜻 허용되어서는 안 된다는 의견을 갖고 있습니다.
#
# Number of turns: 24
